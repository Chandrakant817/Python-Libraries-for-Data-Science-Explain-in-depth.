# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-0b01b43a-d4b4-49d8-af68-bbea4bf46fb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b01b43a-d4b4-49d8-af68-bbea4bf46fb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Fortune.csv to Fortune.csv

# %%
import pandas as pd

# %%
#importing pandas library
df=pd.read_csv("Fortune.csv")
df
# Out:
#    ID             Name            Companies  ...          Expenses    Profit Growth
# 0   1          Lamtone          IT Services  ...   6482500 Dollars   5274553    30%
# 1   2        stripfind   Financial Services  ...    916455 Dollars  11412916    20%
# 2   3  Canecorporation               Health  ...   7591189 Dollars   3005820     7%
# 3   4         Mattouch          IT Services  ...   7429377 Dollars   6597557    NaN
# 4   5        Techdrill                  NaN  ...   7435363 Dollars   3038627    NaN
# 5   6         Techline                  NaN  ...   5470303 Dollars   8427816    NaN
# 6   7          Cityace                  NaN  ...  6249498  Dollars   3005116    16%
# 7   8    Kayelectronic                  NaN  ...   3878113 Dollars   5573830     4%
# 8   9          Ganzlax          IT Services  ...   3878153 Dollars  11907780    18%
# 9  10      Trantraxlax  Government Services  ...   5635276 Dollars   5453060     7%
#
# [10 rows x 8 columns]

# %%
#Nan means values are missing
df.head(10)
# Out:
#    ID             Name            Companies  ...          Expenses    Profit Growth
# 0   1          Lamtone          IT Services  ...   6482500 Dollars   5274553    30%
# 1   2        stripfind   Financial Services  ...    916455 Dollars  11412916    20%
# 2   3  Canecorporation               Health  ...   7591189 Dollars   3005820     7%
# 3   4         Mattouch          IT Services  ...   7429377 Dollars   6597557    NaN
# 4   5        Techdrill                  NaN  ...   7435363 Dollars   3038627    NaN
# 5   6         Techline                  NaN  ...   5470303 Dollars   8427816    NaN
# 6   7          Cityace                  NaN  ...  6249498  Dollars   3005116    16%
# 7   8    Kayelectronic                  NaN  ...   3878113 Dollars   5573830     4%
# 8   9          Ganzlax          IT Services  ...   3878153 Dollars  11907780    18%
# 9  10      Trantraxlax  Government Services  ...   5635276 Dollars   5453060     7%
#
# [10 rows x 8 columns]

# %% [markdown]
# Handling Missing Values

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-99797b70-e0d7-483f-aaee-149c00eb8a65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99797b70-e0d7-483f-aaee-149c00eb8a65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Fortune1.csv to Fortune1.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("Fortune1.csv")

# %%
df.head()
# Out:
#    ID             Name  ...    Profit         Growth
# 0   1          Lamtone  ...   5274553            30%
# 1   2        stripfind  ...  11412916            20%
# 2   3  Canecorporation  ...   3005820             7%
# 3   4         Mattouch  ...   6597557  not available
# 4   5        Techdrill  ...   3038627            NaN
#
# [5 rows x 8 columns]

# %%
df.describe()
# Out:
#              ID    Inception        Profit
# count  10.00000    10.000000  1.000000e+01
# mean    5.50000  2010.000000  6.369708e+06
# std     3.02765     1.943651  3.279520e+06
# min     1.00000  2006.000000  3.005116e+06
# 25%     3.25000  2009.000000  3.597608e+06
# 50%     5.50000  2010.000000  5.513445e+06
# 75%     7.75000  2011.000000  7.970251e+06
# max    10.00000  2013.000000  1.190778e+07

# %%
#na_values
df=pd.read_csv("Fortune1.csv",na_values="not available")
df
# Out:
#    ID             Name            Companies  ...          Expenses    Profit Growth
# 0   1          Lamtone          IT Services  ...   6482500 Dollars   5274553    30%
# 1   2        stripfind   Financial Services  ...    916455 Dollars  11412916    20%
# 2   3  Canecorporation               Health  ...   7591189 Dollars   3005820     7%
# 3   4         Mattouch          IT Services  ...   7429377 Dollars   6597557    NaN
# 4   5        Techdrill            no values  ...   7435363 Dollars   3038627    NaN
# 5   6         Techline            no values  ...   5470303 Dollars   8427816    NaN
# 6   7          Cityace                  NaN  ...  6249498  Dollars   3005116    16%
# 7   8    Kayelectronic                  NaN  ...   3878113 Dollars   5573830     4%
# 8   9          Ganzlax          IT Services  ...   3878153 Dollars  11907780    18%
# 9  10      Trantraxlax  Government Services  ...   5635276 Dollars   5453060     7%
#
# [10 rows x 8 columns]

# %%
#na_values
#na_values in List
df=pd.read_csv("Fortune1.csv",na_values=["not available","no values"])
df
# Out:
#    ID             Name            Companies  ...          Expenses    Profit Growth
# 0   1          Lamtone          IT Services  ...   6482500 Dollars   5274553    30%
# 1   2        stripfind   Financial Services  ...    916455 Dollars  11412916    20%
# 2   3  Canecorporation               Health  ...   7591189 Dollars   3005820     7%
# 3   4         Mattouch          IT Services  ...   7429377 Dollars   6597557    NaN
# 4   5        Techdrill                  NaN  ...   7435363 Dollars   3038627    NaN
# 5   6         Techline                  NaN  ...   5470303 Dollars   8427816    NaN
# 6   7          Cityace                  NaN  ...  6249498  Dollars   3005116    16%
# 7   8    Kayelectronic                  NaN  ...   3878113 Dollars   5573830     4%
# 8   9          Ganzlax          IT Services  ...   3878153 Dollars  11907780    18%
# 9  10      Trantraxlax  Government Services  ...   5635276 Dollars   5453060     7%
#
# [10 rows x 8 columns]

# %%
#na_values
#na_values in Dict
df=pd.read_csv("Fortune1.csv",na_values={"Companies":"no values",
                                         "Growth":"not available"})
df
# Out:
#    ID             Name            Companies  ...          Expenses    Profit Growth
# 0   1          Lamtone          IT Services  ...   6482500 Dollars   5274553    30%
# 1   2        stripfind   Financial Services  ...    916455 Dollars  11412916    20%
# 2   3  Canecorporation               Health  ...   7591189 Dollars   3005820     7%
# 3   4         Mattouch          IT Services  ...   7429377 Dollars   6597557    NaN
# 4   5        Techdrill                  NaN  ...   7435363 Dollars   3038627    NaN
# 5   6         Techline                  NaN  ...   5470303 Dollars   8427816    NaN
# 6   7          Cityace                  NaN  ...  6249498  Dollars   3005116    16%
# 7   8    Kayelectronic                  NaN  ...   3878113 Dollars   5573830     4%
# 8   9          Ganzlax          IT Services  ...   3878153 Dollars  11907780    18%
# 9  10      Trantraxlax  Government Services  ...   5635276 Dollars   5453060     7%
#
# [10 rows x 8 columns]

# %%
#keep_dafault_na
#It will print as it,it will not change any thing
df=pd.read_csv("Fortune1.csv",keep_default_na=False)
df
# Out:
#    ID             Name  ...    Profit         Growth
# 0   1          Lamtone  ...   5274553            30%
# 1   2        stripfind  ...  11412916            20%
# 2   3  Canecorporation  ...   3005820             7%
# 3   4         Mattouch  ...   6597557  not available
# 4   5        Techdrill  ...   3038627
# 5   6         Techline  ...   8427816  not available
# 6   7          Cityace  ...   3005116            16%
# 7   8    Kayelectronic  ...   5573830             4%
# 8   9          Ganzlax  ...  11907780            18%
# 9  10      Trantraxlax  ...   5453060             7%
#
# [10 rows x 8 columns]

# %%
#na_filter
#Note-all the values sholud be present before applying na_filter
df=pd.read_csv("Fortune.csv")
df
# Out:
#    ID             Name            Companies  ...          Expenses    Profit Growth
# 0   1          Lamtone          IT Services  ...   6482500 Dollars   5274553    30%
# 1   2        stripfind   Financial Services  ...    916455 Dollars  11412916    20%
# 2   3  Canecorporation               Health  ...   7591189 Dollars   3005820     7%
# 3   4         Mattouch          IT Services  ...   7429377 Dollars   6597557    NaN
# 4   5        Techdrill                  NaN  ...   7435363 Dollars   3038627    NaN
# 5   6         Techline                  NaN  ...   5470303 Dollars   8427816    NaN
# 6   7          Cityace                  NaN  ...  6249498  Dollars   3005116    16%
# 7   8    Kayelectronic                  NaN  ...   3878113 Dollars   5573830     4%
# 8   9          Ganzlax          IT Services  ...   3878153 Dollars  11907780    18%
# 9  10      Trantraxlax  Government Services  ...   5635276 Dollars   5453060     7%
#
# [10 rows x 8 columns]

# %%
#isnull
df.isnull()
# Out:
#       ID   Name  Companies  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False      False      False    False     False   False   False
# 1  False  False      False      False    False     False   False   False
# 2  False  False      False      False    False     False   False   False
# 3  False  False      False      False    False     False   False    True
# 4  False  False       True      False    False     False   False    True
# 5  False  False       True      False    False     False   False    True
# 6  False  False       True      False    False     False   False   False
# 7  False  False       True      False    False     False   False   False
# 8  False  False      False      False    False     False   False   False
# 9  False  False      False      False    False     False   False   False

# %%
#isnull.sum()
df.isnull().sum()
# Out:
# ID           0
# Name         0
# Companies    4
# Inception    0
# Revenue      0
# Expenses     0
# Profit       0
# Growth       3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 7

# %%
#not null
df.notnull()
# Out:
#      ID  Name  Companies  Inception  Revenue  Expenses  Profit  Growth
# 0  True  True       True       True     True      True    True    True
# 1  True  True       True       True     True      True    True    True
# 2  True  True       True       True     True      True    True    True
# 3  True  True       True       True     True      True    True   False
# 4  True  True      False       True     True      True    True   False
# 5  True  True      False       True     True      True    True   False
# 6  True  True      False       True     True      True    True    True
# 7  True  True      False       True     True      True    True    True
# 8  True  True       True       True     True      True    True    True
# 9  True  True       True       True     True      True    True    True

# %%
df.notnull().sum()
# Out:
# ID           10
# Name         10
# Companies     6
# Inception    10
# Revenue      10
# Expenses     10
# Profit       10
# Growth        7
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 73

# %%
import numpy as np

# %%
df=pd.Series([1,2,3,np.NaN,4,np.NaN])
df
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
df.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# 2

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-3b0142c1-f13f-4afa-b660-11e349f10309" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b0142c1-f13f-4afa-b660-11e349f10309">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Fortune2.csv to Fortune2 (1).csv

# %%
import pandas as pd

# %%
df=pd.read_csv("Fortune2.csv")
df
# Out:
#     ID             Name           Companies  ...         Expenses      Profit Growth
# 0  1.0          Lamtone         IT Services  ...  6482500 Dollars   5274553.0    30%
# 1  2.0        stripfind  Financial Services  ...   916455 Dollars  11412916.0    20%
# 2  3.0  Canecorporation              Health  ...  7591189 Dollars   3005820.0     7%
# 3  4.0              NaN         IT Services  ...  7429377 Dollars   6597557.0    NaN
# 4  5.0        Techdrill                 NaN  ...  7435363 Dollars   3038627.0    21%
# 5  NaN              NaN                 NaN  ...              NaN         NaN    NaN
# 6  NaN              NaN                 NaN  ...              NaN         NaN    NaN
# 7  NaN              NaN                 NaN  ...              NaN         NaN    NaN
# 8  NaN              NaN                 NaN  ...              NaN         NaN    NaN
# 9  NaN              NaN                 NaN  ...              NaN         NaN    NaN
#
# [10 rows x 8 columns]

# %%
df.dropna()
# Out:
#     ID             Name           Companies  ...         Expenses      Profit Growth
# 0  1.0          Lamtone         IT Services  ...  6482500 Dollars   5274553.0    30%
# 1  2.0        stripfind  Financial Services  ...   916455 Dollars  11412916.0    20%
# 2  3.0  Canecorporation              Health  ...  7591189 Dollars   3005820.0     7%
#
# [3 rows x 8 columns]

# %%
df.dropna(how="any")
# Out:
#     ID             Name           Companies  ...         Expenses      Profit Growth
# 0  1.0          Lamtone         IT Services  ...  6482500 Dollars   5274553.0    30%
# 1  2.0        stripfind  Financial Services  ...   916455 Dollars  11412916.0    20%
# 2  3.0  Canecorporation              Health  ...  7591189 Dollars   3005820.0     7%
#
# [3 rows x 8 columns]

# %%
df.dropna(how="all")
# Out:
#     ID             Name           Companies  ...         Expenses      Profit Growth
# 0  1.0          Lamtone         IT Services  ...  6482500 Dollars   5274553.0    30%
# 1  2.0        stripfind  Financial Services  ...   916455 Dollars  11412916.0    20%
# 2  3.0  Canecorporation              Health  ...  7591189 Dollars   3005820.0     7%
# 3  4.0              NaN         IT Services  ...  7429377 Dollars   6597557.0    NaN
# 4  5.0        Techdrill                 NaN  ...  7435363 Dollars   3038627.0    21%
#
# [5 rows x 8 columns]

# %%
df.dropna(thresh=1)
# Out:
#     ID             Name           Companies  ...         Expenses      Profit Growth
# 0  1.0          Lamtone         IT Services  ...  6482500 Dollars   5274553.0    30%
# 1  2.0        stripfind  Financial Services  ...   916455 Dollars  11412916.0    20%
# 2  3.0  Canecorporation              Health  ...  7591189 Dollars   3005820.0     7%
# 3  4.0              NaN         IT Services  ...  7429377 Dollars   6597557.0    NaN
# 4  5.0        Techdrill                 NaN  ...  7435363 Dollars   3038627.0    21%
#
# [5 rows x 8 columns]

# %%
df.dropna(subset=["Name"])
# Out:
#     ID             Name           Companies  ...         Expenses      Profit Growth
# 0  1.0          Lamtone         IT Services  ...  6482500 Dollars   5274553.0    30%
# 1  2.0        stripfind  Financial Services  ...   916455 Dollars  11412916.0    20%
# 2  3.0  Canecorporation              Health  ...  7591189 Dollars   3005820.0     7%
# 4  5.0        Techdrill                 NaN  ...  7435363 Dollars   3038627.0    21%
#
# [4 rows x 8 columns]

# %%
df.dropna(subset=["Name","Companies"])
# Out:
#     ID             Name           Companies  ...         Expenses      Profit Growth
# 0  1.0          Lamtone         IT Services  ...  6482500 Dollars   5274553.0    30%
# 1  2.0        stripfind  Financial Services  ...   916455 Dollars  11412916.0    20%
# 2  3.0  Canecorporation              Health  ...  7591189 Dollars   3005820.0     7%
#
# [3 rows x 8 columns]
