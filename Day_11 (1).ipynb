# %% [markdown]
# Histogram

# %%
#importing the Library
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
ml_students_age=np.random.randint(18,45,(100))
py_students_age=np.random.randint(15,40,(100))

# %%
print(ml_students_age)
print(py_students_age)
# Out:
# [32 22 43 34 39 43 36 29 35 38 36 35 40 31 32 33 40 25 20 26 41 29 38 33
#  33 38 25 34 26 27 39 32 25 28 35 39 37 25 43 23 23 40 26 36 42 29 33 22
#  30 37 31 25 35 37 20 32 28 43 39 39 19 19 41 26 24 35 42 42 43 36 38 41
#  38 24 37 21 27 27 35 29 20 41 26 33 18 33 24 34 34 20 18 29 30 22 25 33
#  29 43 39 43]
# [23 17 30 17 16 21 16 29 32 29 34 39 20 20 18 18 17 36 31 28 39 38 29 28
#  19 31 16 15 21 35 34 35 22 22 23 33 17 37 24 30 33 33 31 33 36 34 30 28
#  28 34 20 33 26 37 20 20 24 20 31 31 22 20 17 20 37 30 27 17 29 27 36 26
#  39 25 25 33 24 20 31 15 21 32 39 31 30 15 24 26 19 27 30 28 29 28 22 38
#  24 18 28 29]

# %%
#hist
plt.hist(ml_students_age)
plt.title("Ml students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.show()

# %%
bins=[15,20,25,30,35,40,45]
plt.hist(ml_students_age,bins)
plt.title("Ml students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.show()

# %%
#Applying Width
bins=[15,20,25,30,35,40,45]
plt.hist(ml_students_age,bins,rwidth=0.8)
plt.title("Ml students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.show()

# %%
#histtype
#Applying Width
bins=[15,20,25,30,35,40,45]
plt.hist(ml_students_age,bins,rwidth=0.8,histtype="step")
plt.title("Ml students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.show()

# %%
#histtype
#Applying histtype
bins=[15,20,25,30,35,40,45]
plt.hist(ml_students_age,bins,rwidth=0.8,histtype="bar")
plt.title("Ml students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.show()

# %%
#Orientation
#histtype
#Applying Width
bins=[15,20,25,30,35,40,45]
plt.hist(ml_students_age,bins,rwidth=0.8,histtype="bar",orientation="horizontal")
plt.title("Ml students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.show()

# %%
#color
bins=[15,20,25,30,35,40,45]
plt.hist(ml_students_age,bins,rwidth=0.8,histtype="bar",orientation="horizontal",color="y")
plt.title("Ml students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.show()

# %%
#Label
bins=[15,20,25,30,35,40,45]
plt.hist(ml_students_age,bins,rwidth=0.8,histtype="bar",orientation="horizontal",color="m",label="ML Students")
plt.title("Ml students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.legend()
plt.show()

# %%
#color
bins=[15,20,25,30,35,40,45]

plt.hist(ml_students_age,bins,rwidth=0.8,histtype="bar",orientation="vertical",color="m",label="ML Student")
plt.hist(py_students_age,bins,rwidth=0.8,histtype="bar",orientation="vertical",color="y",label="PY Student")

plt.title("Ml students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.legend()
plt.show()

# %%
#color
bins=[15,20,25,30,35,40,45]

plt.hist([ml_students_age,py_students_age],bins,rwidth=0.8,histtype="bar",orientation="vertical",color=["m","y"],label=["ML Student","PY Students"])

plt.title("Ml and Py students age")
plt.xlabel("Students age category")
plt.ylabel("Number of students age")
plt.legend()
plt.show()

# %%
#color
bins=[15,20,25,30,35,40,45]
plt.figure(figsize=(16,9)) #ratio in 16:9

plt.hist([ml_students_age,py_students_age],bins,rwidth=0.8,histtype="bar",orientation="vertical",color=["m","y"],label=["ML Student","PY Students"])

plt.title("Ml and PY students age",fontsize=20)
plt.xlabel("Students age category",fontsize=15)
plt.ylabel("Number of students age",fontsize=15)
plt.legend(fontsize=10)
plt.show()

# %%
#color
from matplotlib import style
style.use("ggplot")
bins=[15,20,25,30,35,40,45]
plt.figure(figsize=(16,9)) #ratio in 16:9

plt.hist([ml_students_age,py_students_age],bins,rwidth=0.8,histtype="bar",orientation="vertical",color=["m","y"],label=["ML Student","PY Students"])

plt.title("Ml and PY students age",fontsize=20)
plt.xlabel("Students age category",fontsize=15)
plt.ylabel("Number of students age",fontsize=15)
plt.legend(fontsize=10)
plt.show()

# %% [markdown]
# Bar Chart

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

# %%
classes=["Python","R","AI","ML","DS"]
class1_Students=[30,10,20,25,10]
class2_Students=[40,5,20,20,10]
class3_Students=[35,5,30,15,15]

# %%
plt.bar(classes,class1_Students)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(classes,class1_Students)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(classes,class1_Students,width=0.3,align="edge",label="class1_students",color="y")

plt.title("Class1 Students")
plt.xlabel("Courses")
plt.ylabel("Students")
plt.legend()
plt.show()

# %%
plt.bar(classes,class1_Students,width=0.3,align="edge",color="y",edgecolor="m",linewidth=5)

plt.title("Class1 Students")
plt.xlabel("Courses")
plt.ylabel("Students")
plt.show()

# %%
#alpha (To change the opacity from[0 to 1 range as a float])
plt.bar(classes,class1_Students,width=0.3,align="edge",color="y",edgecolor="m",linewidth=5,linestyle=":",alpha=0.8,label="Class1 Students")

plt.title("Class1 Students",fontsize=15)
plt.xlabel("Courses",fontsize=10)
plt.ylabel("Students",fontsize=10)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.bar(classes,class1_Students,width=0.3,align="edge",color="k",edgecolor="m",linewidth=5,linestyle=":",alpha=0.8,label="Class1 Students")
#k->black
plt.title("Class1 Students",fontsize=15)
plt.xlabel("Courses",fontsize=15)
plt.ylabel("Students",fontsize=15)
plt.legend()
plt.show()

# %%
#xticks=(ticks=None,labels=None)
plt.figure(figsize=(15,9))
class_index=np.arange(len(classes))
width=0.2

plt.bar(class_index,class1_Students,width,color="b",label="class1 Students")
plt.bar(class_index+width,class2_Students,width,color="g",label="class2 Students")
plt.bar(class_index+width+width,class3_Students,width,color="y",label="class3 Students")

plt.xticks(class_index+width,classes,rotation=20)
plt.title("Bar Chart of CLASSES")
plt.xlabel("Classes",fontsize=15)
plt.ylabel("No. of students",fontsize=15)
plt.show()

# %%
#yticks=(ticks=None,labels=None)
plt.figure(figsize=(15,9))
class_index=np.arange(len(classes))
width=0.2

plt.barh(class_index,class1_Students,width,color="b",label="class1 Students")
plt.barh(class_index+width,class2_Students,width,color="g",label="class2 Students")
plt.barh(class_index+width+width,class3_Students,width,color="y",label="class3 Students")

plt.yticks(class_index+width,classes,rotation=20)
plt.title("Bar Chart of CLASSES")
plt.xlabel("Classes",fontsize=15)
plt.ylabel("No. of students",fontsize=15)
plt.show()
